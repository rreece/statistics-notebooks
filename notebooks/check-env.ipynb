# %%
3+1
# Out:
# 4

# %%
# %env PYTHONPATH
# Out:
# '/Users/reece/at-github/statistics-notebooks/python:'

# %%
# %env PATH
# Out:
# '/Users/reece/at-github/statistics-notebooks/scripts:/Users/reece/at-github/statistics-notebooks/env1/bin:/Users/reece/.local/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/TeX/texbin:/opt/X11/bin:'

# %%
# !which python3
# Out:
# /Users/reece/at-github/statistics-notebooks/env1/bin/python3

# %%
# !which python
# Out:
# /Users/reece/at-github/statistics-notebooks/env1/bin/python

# %%
# !which jupyter
# Out:
# /Users/reece/at-github/statistics-notebooks/env1/bin/jupyter

# %%
import easyplot
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import mplhep

# %%
import hepplot
